# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
import os
import glob
# %matplotlib inline
#sns.set()

# %%
path = r'rnd/2013-8/'                     # use your path
all_files = glob.glob(os.path.join(path, "1*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

df_from_each_file = (pd.read_csv(f, sep = ';\t') for f in all_files)
concatenated_df   = pd.concat(df_from_each_file)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.

# %%
concatenated_df['Timestamp'] = pd.to_datetime(concatenated_df['Timestamp [ms]'], unit = 's')
concatenated_df.apply(pd.to_numeric, errors='ignore')
concatenated_df.describe()
# Out:
#        Timestamp [ms]      CPU cores  CPU capacity provisioned [MHZ]  \
# count    9.569690e+05  956969.000000                   956969.000000
# mean     1.376604e+09       2.882605                     7709.137737
# std      7.477136e+05       1.399861                     3767.003529
# min      1.375308e+09       0.000000                        0.000000
# 25%      1.375957e+09       1.000000                     2925.999318
# 50%      1.376604e+09       4.000000                    10399.997204
# 75%      1.377252e+09       4.000000                    10399.998464
# max      1.377900e+09       4.000000                    11704.001168
#
#        CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# count    956969.000000  956969.000000                      9.569690e+05
# mean        432.905429       4.556463                      6.283470e+06
# std        1647.829960      15.764931                      5.785848e+06
# min           0.000000       0.000000                      0.000000e+00
# 25%          25.999997       1.000000                      2.105344e+06
# 50%         152.151965       1.516667                      3.024896e+06
# 75%         183.733305       1.833333                      8.357888e+06
# max       11454.312686     105.166667                      1.677722e+07
#
#        Memory usage [KB]  Disk read throughput [KB/s]  \
# count       9.569690e+05                956969.000000
# mean        2.579660e+05                     6.646575
# std         7.342356e+05                   281.415375
# min         0.000000e+00                     0.000000
# 25%         4.473707e+04                     0.000000
# 50%         1.230328e+05                     0.000000
# 75%         2.013264e+05                     0.000000
# max         1.533437e+07                 81284.600000
#
#        Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# count                 956969.000000                       956969.000000
# mean                      42.370781                            8.336966
# std                      578.814712                          219.713627
# min                        0.000000                            0.000000
# 25%                        2.400000                            0.000000
# 50%                        8.933333                            1.000000
# 75%                       12.466667                            4.533333
# max                    91548.000000                        92393.500000
#
#        Network transmitted throughput [KB/s]
# count                          956969.000000
# mean                               10.237593
# std                               284.811822
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.200000
# max                             50715.733333

# %%
concatenated_df.head()
# Out:
#    Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  CPU usage [MHZ]  \
# 0      1375308176          2                       5851.9989       747.105193
# 1      1375308476          2                       5851.9989       672.979873
# 2      1375308776          2                       5851.9989       743.203860
# 3      1375309076          2                       5851.9989       758.809191
# 4      1375309376          2                       5851.9989       661.275876
#
#    CPU usage [%]  Memory capacity provisioned [KB]  Memory usage [KB]  \
# 0      12.766667                         8388608.0          1308620.0
# 1      11.500000                         8388608.0          1157626.4
# 2      12.700000                         8388608.0          1157625.6
# 3      12.966667                         8388608.0          1073740.8
# 4      11.300000                         8388608.0           973076.0
#
#    Disk read throughput [KB/s]  Disk write throughput [KB/s]  \
# 0                          0.0                      1.000000
# 1                          0.0                      1.000000
# 2                          0.0                      1.000000
# 3                          0.0                      1.000000
# 4                          0.0                      0.933333
#
#    Network received throughput [KB/s]  Network transmitted throughput [KB/s]  \
# 0                           11.000000                              27.200000
# 1                           13.466667                              30.666667
# 2                           13.400000                              33.466667
# 3                           11.866667                              27.666667
# 4                           13.333333                              31.933333
#
#             Timestamp
# 0 2013-07-31 22:02:56
# 1 2013-07-31 22:07:56
# 2 2013-07-31 22:12:56
# 3 2013-07-31 22:17:56
# 4 2013-07-31 22:22:56

# %%
concatenated_df['Timestamp'] = pd.to_datetime(concatenated_df['Timestamp [ms]'], unit = 's')
concatenated_df.apply(pd.to_numeric, errors='ignore')
concatenated_df.describe()
concatenated_df['weekday'] = concatenated_df['Timestamp'].dt.dayofweek


concatenated_df['weekend'] = ((concatenated_df.weekday) // 5 == 1).astype(float)
# Feature engineering with the date
concatenated_df['month']=concatenated_df.Timestamp.dt.month 
concatenated_df['day']=concatenated_df.Timestamp.dt.day
concatenated_df.set_index('Timestamp',inplace=True)

# %%
concatenated_df["CPU usage prev"] = concatenated_df['CPU usage [%]'].shift(1)

# %%
concatenated_df["CPU_diff"] = concatenated_df['CPU usage [%]'] - concatenated_df["CPU usage prev"]
concatenated_df.head()
# Out:
#                      CPU cores  CPU usage [MHZ]  CPU usage [%]  \
# Timestamp
# 2013-07-31 22:02:56          2       747.105193      12.766667
# 2013-07-31 22:07:56          2       672.979873      11.500000
# 2013-07-31 22:12:56          2       743.203860      12.700000
# 2013-07-31 22:17:56          2       758.809191      12.966667
# 2013-07-31 22:22:56          2       661.275876      11.300000
#
#                      Disk read throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:02:56                          0.0
# 2013-07-31 22:07:56                          0.0
# 2013-07-31 22:12:56                          0.0
# 2013-07-31 22:17:56                          0.0
# 2013-07-31 22:22:56                          0.0
#
#                      Disk write throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:02:56                      1.000000
# 2013-07-31 22:07:56                      1.000000
# 2013-07-31 22:12:56                      1.000000
# 2013-07-31 22:17:56                      1.000000
# 2013-07-31 22:22:56                      0.933333
#
#                      Network received throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:02:56                           11.000000
# 2013-07-31 22:07:56                           13.466667
# 2013-07-31 22:12:56                           13.400000
# 2013-07-31 22:17:56                           11.866667
# 2013-07-31 22:22:56                           13.333333
#
#                      Network transmitted throughput [KB/s]  weekday  weekend  \
# Timestamp
# 2013-07-31 22:02:56                              27.200000        2      0.0
# 2013-07-31 22:07:56                              30.666667        2      0.0
# 2013-07-31 22:12:56                              33.466667        2      0.0
# 2013-07-31 22:17:56                              27.666667        2      0.0
# 2013-07-31 22:22:56                              31.933333        2      0.0
#
#                      year  month  day  CPU usage prev  CPU_diff
# Timestamp
# 2013-07-31 22:02:56  2013      7   31             NaN       NaN
# 2013-07-31 22:07:56  2013      7   31       12.766667 -1.266667
# 2013-07-31 22:12:56  2013      7   31       11.500000  1.200000
# 2013-07-31 22:17:56  2013      7   31       12.700000  0.266667
# 2013-07-31 22:22:56  2013      7   31       12.966667 -1.666667

# %%
concatenated_df["received_prev"] = concatenated_df['Network received throughput [KB/s]'].shift(1)
concatenated_df["received_diff"] = concatenated_df['Network received throughput [KB/s]']- concatenated_df["received_prev"]

concatenated_df["transmitted_prev"] = concatenated_df['Network transmitted throughput [KB/s]'].shift(1)
concatenated_df["transmitted_diff"] = concatenated_df['Network transmitted throughput [KB/s]']- concatenated_df["transmitted_prev"]
concatenated_df.head()
# Out:
#                      CPU cores  CPU usage [MHZ]  CPU usage [%]  \
# Timestamp
# 2013-07-31 22:02:56          2       747.105193      12.766667
# 2013-07-31 22:07:56          2       672.979873      11.500000
# 2013-07-31 22:12:56          2       743.203860      12.700000
# 2013-07-31 22:17:56          2       758.809191      12.966667
# 2013-07-31 22:22:56          2       661.275876      11.300000
#
#                      Disk read throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:02:56                          0.0
# 2013-07-31 22:07:56                          0.0
# 2013-07-31 22:12:56                          0.0
# 2013-07-31 22:17:56                          0.0
# 2013-07-31 22:22:56                          0.0
#
#                      Disk write throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:02:56                      1.000000
# 2013-07-31 22:07:56                      1.000000
# 2013-07-31 22:12:56                      1.000000
# 2013-07-31 22:17:56                      1.000000
# 2013-07-31 22:22:56                      0.933333
#
#                      Network received throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:02:56                           11.000000
# 2013-07-31 22:07:56                           13.466667
# 2013-07-31 22:12:56                           13.400000
# 2013-07-31 22:17:56                           11.866667
# 2013-07-31 22:22:56                           13.333333
#
#                      Network transmitted throughput [KB/s]  weekday  weekend  \
# Timestamp
# 2013-07-31 22:02:56                              27.200000        2      0.0
# 2013-07-31 22:07:56                              30.666667        2      0.0
# 2013-07-31 22:12:56                              33.466667        2      0.0
# 2013-07-31 22:17:56                              27.666667        2      0.0
# 2013-07-31 22:22:56                              31.933333        2      0.0
#
#                      year  month  day  CPU usage prev  CPU_diff  \
# Timestamp
# 2013-07-31 22:02:56  2013      7   31             NaN       NaN
# 2013-07-31 22:07:56  2013      7   31       12.766667 -1.266667
# 2013-07-31 22:12:56  2013      7   31       11.500000  1.200000
# 2013-07-31 22:17:56  2013      7   31       12.700000  0.266667
# 2013-07-31 22:22:56  2013      7   31       12.966667 -1.666667
#
#                      received_prev  received_diff  transmitted_prev  \
# Timestamp
# 2013-07-31 22:02:56            NaN            NaN               NaN
# 2013-07-31 22:07:56      11.000000       2.466667         27.200000
# 2013-07-31 22:12:56      13.466667      -0.066667         30.666667
# 2013-07-31 22:17:56      13.400000      -1.533333         33.466667
# 2013-07-31 22:22:56      11.866667       1.466667         27.666667
#
#                      transmitted_diff
# Timestamp
# 2013-07-31 22:02:56               NaN
# 2013-07-31 22:07:56          3.466667
# 2013-07-31 22:12:56          2.800000
# 2013-07-31 22:17:56         -5.800000
# 2013-07-31 22:22:56          4.266667

# %%
cpu = concatenated_df[['CPU usage [%]']]
receive = concatenated_df[['Network received throughput [KB/s]']]
transmit = concatenated_df[['Network transmitted throughput [KB/s]']]
concatenated_df.drop('CPU capacity provisioned [MHZ]', axis=1, inplace=True)
concatenated_df.drop('Memory capacity provisioned [KB]', axis=1, inplace=True)
concatenated_df.drop('Timestamp [ms]', axis=1, inplace=True) 
concatenated_df.drop('Memory usage [KB]', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-297-03e371e5cdb4> in <module>()
#       2 receive = concatenated_df[['Network received throughput [KB/s]']]
#       3 transmit = concatenated_df[['Network transmitted throughput [KB/s]']]
# ----> 4 concatenated_df.drop('CPU capacity provisioned [MHZ]', axis=1, inplace=True)
#       5 concatenated_df.drop('Memory capacity provisioned [KB]', axis=1, inplace=True)
#       6 concatenated_df.drop('Timestamp [ms]', axis=1, inplace=True)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels ['CPU capacity provisioned [MHZ]'] not contained in axis

# %%
concatenated_df.drop('year', axis=1, inplace=True)

# %%
concatenated_df.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Date', fontsize=20);

# %%
df_rm = pd.concat([cpu.rolling(12).mean(), receive.rolling(12).mean(), transmit.rolling(12).mean()], axis=1)
df_rm.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Date', fontsize=20);

# %%
def moving_average(series, n):
    """
        Calculate average of last n observations
    """
    return np.average(series[-n:])

moving_average(cpu, 24) # prediction for the last observed day (past 24 hours)
# Out:
# 2.1166666666666667

# %%
hourlycpu = cpu.resample('H').mean()
hourlycpu.plot(style=[':', '--', '-'])
plt.ylabel('CPU Usage Avg %');

hourlytransmit = transmit.resample('H').mean()
hourlytransmit.plot(style=[':', '--', '-'])
plt.ylabel('Transmitted Throughput [KB/s]');

hourlyreceive = receive.resample('H').mean()
hourlyreceive.plot(style=[':', '--', '-'])
plt.ylabel('Received Throughput [KB/s]');

# %%
hourlycpu = cpu.resample('H').mean()
hourlycpu[400:500].plot(style=[':', '--', '-'])
plt.ylabel('CPU Usage Avg %');

# %%
hourlydat = concatenated_df.resample('H').mean()
hourlydat.plot(style=[':', '--', '-'], figsize=(20,10), linewidth=3, fontsize=20)

plt.ylabel('Resampled Data');

# %%
concatenated_df.corr()
# Out:
#                                        CPU cores  CPU usage [MHZ]  \
# CPU cores                               1.000000         0.172736
# CPU usage [MHZ]                         0.172736         1.000000
# CPU usage [%]                           0.137127         0.984904
# Disk read throughput [KB/s]            -0.019693         0.010015
# Disk write throughput [KB/s]            0.042327         0.331160
# Network received throughput [KB/s]      0.006276         0.016416
# Network transmitted throughput [KB/s]  -0.015694         0.016318
# weekday                                 0.000868        -0.019038
# weekend                                 0.000163        -0.020458
# month                                   0.006110         0.009327
# day                                     0.049031        -0.036529
# CPU usage prev                          0.137099         0.939090
# CPU_diff                                0.000093         0.150911
# received_prev                           0.006268         0.021410
# received_diff                           0.000007        -0.004565
# transmitted_prev                       -0.015700         0.011930
# transmitted_diff                        0.000009         0.006690
#
#                                        CPU usage [%]  \
# CPU cores                                   0.137127
# CPU usage [MHZ]                             0.984904
# CPU usage [%]                               1.000000
# Disk read throughput [KB/s]                 0.018584
# Disk write throughput [KB/s]                0.296319
# Network received throughput [KB/s]          0.023456
# Network transmitted throughput [KB/s]       0.026351
# weekday                                    -0.017386
# weekend                                    -0.019343
# month                                       0.008820
# day                                        -0.038245
# CPU usage prev                              0.953920
# CPU_diff                                    0.151790
# received_prev                               0.026570
# received_diff                              -0.002847
# transmitted_prev                            0.020108
# transmitted_diff                            0.009521
#
#                                        Disk read throughput [KB/s]  \
# CPU cores                                                -0.019693
# CPU usage [MHZ]                                           0.010015
# CPU usage [%]                                             0.018584
# Disk read throughput [KB/s]                               1.000000
# Disk write throughput [KB/s]                              0.088793
# Network received throughput [KB/s]                        0.152483
# Network transmitted throughput [KB/s]                     0.908457
# weekday                                                   0.003675
# weekend                                                  -0.008962
# month                                                     0.001027
# day                                                      -0.014710
# CPU usage prev                                            0.015710
# CPU_diff                                                  0.009468
# received_prev                                             0.317257
# received_diff                                            -0.150600
# transmitted_prev                                          0.711918
# transmitted_diff                                          0.299708
#
#                                        Disk write throughput [KB/s]  \
# CPU cores                                                  0.042327
# CPU usage [MHZ]                                            0.331160
# CPU usage [%]                                              0.296319
# Disk read throughput [KB/s]                                0.088793
# Disk write throughput [KB/s]                               1.000000
# Network received throughput [KB/s]                         0.354652
# Network transmitted throughput [KB/s]                      0.057565
# weekday                                                   -0.002387
# weekend                                                   -0.005442
# month                                                      0.002771
# day                                                        0.005372
# CPU usage prev                                             0.294894
# CPU_diff                                                   0.004694
# received_prev                                              0.142358
# received_diff                                              0.194031
# transmitted_prev                                           0.080946
# transmitted_diff                                          -0.035655
#
#                                        Network received throughput [KB/s]  \
# CPU cores                                                        0.006276
# CPU usage [MHZ]                                                  0.016416
# CPU usage [%]                                                    0.023456
# Disk read throughput [KB/s]                                      0.152483
# Disk write throughput [KB/s]                                     0.354652
# Network received throughput [KB/s]                               1.000000
# Network transmitted throughput [KB/s]                            0.193526
# weekday                                                         -0.003381
# weekend                                                         -0.008112
# month                                                            0.000646
# day                                                             -0.004867
# CPU usage prev                                                   0.018112
# CPU_diff                                                         0.017601
# received_prev                                                    0.401444
# received_diff                                                    0.547063
# transmitted_prev                                                 0.254513
# transmitted_diff                                                -0.093002
#
#                                        Network transmitted throughput [KB/s]  \
# CPU cores                                                          -0.015694
# CPU usage [MHZ]                                                     0.016318
# CPU usage [%]                                                       0.026351
# Disk read throughput [KB/s]                                         0.908457
# Disk write throughput [KB/s]                                        0.057565
# Network received throughput [KB/s]                                  0.193526
# Network transmitted throughput [KB/s]                               1.000000
# weekday                                                             0.000519
# weekend                                                            -0.014694
# month                                                               0.001656
# day                                                                -0.010955
# CPU usage prev                                                      0.026618
# CPU_diff                                                           -0.000878
# received_prev                                                       0.352764
# received_diff                                                      -0.145539
# transmitted_prev                                                    0.784985
# transmitted_diff                                                    0.327883
#
#                                         weekday   weekend     month       day  \
# CPU cores                              0.000868  0.000163  0.006110  0.049031
# CPU usage [MHZ]                       -0.019038 -0.020458  0.009327 -0.036529
# CPU usage [%]                         -0.017386 -0.019343  0.008820 -0.038245
# Disk read throughput [KB/s]            0.003675 -0.008962  0.001027 -0.014710
# Disk write throughput [KB/s]          -0.002387 -0.005442  0.002771  0.005372
# Network received throughput [KB/s]    -0.003381 -0.008112  0.000646 -0.004867
# Network transmitted throughput [KB/s]  0.000519 -0.014694  0.001656 -0.010955
# weekday                                1.000000  0.768706  0.027997 -0.086379
# weekend                                0.768706  1.000000  0.031895 -0.105508
# month                                  0.027997  0.031895  1.000000 -0.094594
# day                                   -0.086379 -0.105508 -0.094594  1.000000
# CPU usage prev                        -0.017187 -0.019118  0.007924 -0.038181
# CPU_diff                              -0.000655 -0.000742  0.002990 -0.000216
# received_prev                         -0.003366 -0.008109  0.000594 -0.004862
# received_diff                         -0.000014 -0.000003  0.000047 -0.000004
# transmitted_prev                       0.000555 -0.014690  0.001604 -0.010945
# transmitted_diff                      -0.000055 -0.000006  0.000082 -0.000015
#
#                                        CPU usage prev  CPU_diff  \
# CPU cores                                    0.137099  0.000093
# CPU usage [MHZ]                              0.939090  0.150911
# CPU usage [%]                                0.953920  0.151790
# Disk read throughput [KB/s]                  0.015710  0.009468
# Disk write throughput [KB/s]                 0.294894  0.004694
# Network received throughput [KB/s]           0.018112  0.017601
# Network transmitted throughput [KB/s]        0.026618 -0.000878
# weekday                                     -0.017187 -0.000655
# weekend                                     -0.019118 -0.000742
# month                                        0.007924  0.002990
# day                                         -0.038181 -0.000216
# CPU usage prev                               1.000000 -0.151790
# CPU_diff                                    -0.151790  1.000000
# received_prev                                0.023456  0.010260
# received_diff                               -0.004884  0.006709
# transmitted_prev                             0.026351 -0.020567
# transmitted_diff                             0.000407  0.030025
#
#                                        received_prev  received_diff  \
# CPU cores                                   0.006268       0.000007
# CPU usage [MHZ]                             0.021410      -0.004565
# CPU usage [%]                               0.026570      -0.002847
# Disk read throughput [KB/s]                 0.317257      -0.150600
# Disk write throughput [KB/s]                0.142358       0.194031
# Network received throughput [KB/s]          0.401444       0.547063
# Network transmitted throughput [KB/s]       0.352764      -0.145539
# weekday                                    -0.003366      -0.000014
# weekend                                    -0.008109      -0.000003
# month                                       0.000594       0.000047
# day                                        -0.004862      -0.000004
# CPU usage prev                              0.023456      -0.004884
# CPU_diff                                    0.010260       0.006709
# received_prev                               1.000000      -0.547063
# received_diff                              -0.547063       1.000000
# transmitted_prev                            0.193526       0.055741
# transmitted_diff                            0.242828      -0.306939
#
#                                        transmitted_prev  transmitted_diff
# CPU cores                                     -0.015700          0.000009
# CPU usage [MHZ]                                0.011930          0.006690
# CPU usage [%]                                  0.020108          0.009521
# Disk read throughput [KB/s]                    0.711918          0.299708
# Disk write throughput [KB/s]                   0.080946         -0.035655
# Network received throughput [KB/s]             0.254513         -0.093002
# Network transmitted throughput [KB/s]          0.784985          0.327883
# weekday                                        0.000555         -0.000055
# weekend                                       -0.014690         -0.000006
# month                                          0.001604          0.000082
# day                                           -0.010945         -0.000015
# CPU usage prev                                 0.026351          0.000407
# CPU_diff                                      -0.020567          0.030025
# received_prev                                  0.193526          0.242828
# received_diff                                  0.055741         -0.306939
# transmitted_prev                               1.000000         -0.327883
# transmitted_diff                              -0.327883          1.000000

# %%
concatenated_df.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('TIME', fontsize=20);

# %%
hourlycpu.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('TIME', fontsize=20);

# %%
hourlyreceive.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('TIME', fontsize=20);

# %%
hourlyreceive.head()
# Out:
#                      Network received throughput [KB/s]
# Timestamp
# 2013-07-31 22:00:00                            6.067425
# 2013-07-31 23:00:00                            5.236837
# 2013-08-01 00:00:00                            5.705259
# 2013-08-01 01:00:00                            4.202267
# 2013-08-01 02:00:00                            7.355777

# %%
ts_logcpu = np.log(hourlycpu)
ts_logreceive = np.log(hourlyreceive)
ts_logtransmit = np.log(hourlytransmit)

# %%
ts_logreceive.head()
ts_logcpu.head()
# Out:
#                      CPU usage [%]
# Timestamp
# 2013-07-31 22:00:00       0.667108
# 2013-07-31 23:00:00       0.642465
# 2013-08-01 00:00:00       0.645691
# 2013-08-01 01:00:00       0.646989
# 2013-08-01 02:00:00       0.698113

# %%
newdf = ts_logcpu
newdf['Network transmitted throughput [KB/s]'] = ts_logtransmit
newdf['Network received throughput [KB/s]'] = ts_logreceive

# %%
newdf.head()
# Out:
#                      CPU usage [%]  Network transmitted throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:00:00       0.667108                               0.157372
# 2013-07-31 23:00:00       0.642465                               0.372773
# 2013-08-01 00:00:00       0.645691                               0.664127
# 2013-08-01 01:00:00       0.646989                               0.524955
# 2013-08-01 02:00:00       0.698113                               1.272634
#
#                      Network received throughput [KB/s]
# Timestamp
# 2013-07-31 22:00:00                            1.802934
# 2013-07-31 23:00:00                            1.655718
# 2013-08-01 00:00:00                            1.741388
# 2013-08-01 01:00:00                            1.435624
# 2013-08-01 02:00:00                            1.995486

# %%
ts_logcpu = np.log(hourlycpu)
ts_logcpu.head()
# Out:
#                      CPU usage [%]
# Timestamp
# 2013-07-31 22:00:00       0.667108
# 2013-07-31 23:00:00       0.642465
# 2013-08-01 00:00:00       0.645691
# 2013-08-01 01:00:00       0.646989
# 2013-08-01 02:00:00       0.698113

# %%
newdf.plot(figsize=(20,10), linewidth=3, fontsize=20)
plt.xlabel('Day', fontsize=20);

# %%
pd.plotting.autocorrelation_plot(newdf);
newdf.head()
# Out:
#                      CPU usage [%]  Network transmitted throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:00:00       0.667108                               0.157372
# 2013-07-31 23:00:00       0.642465                               0.372773
# 2013-08-01 00:00:00       0.645691                               0.664127
# 2013-08-01 01:00:00       0.646989                               0.524955
# 2013-08-01 02:00:00       0.698113                               1.272634
#
#                      Network received throughput [KB/s]
# Timestamp
# 2013-07-31 22:00:00                            1.802934
# 2013-07-31 23:00:00                            1.655718
# 2013-08-01 00:00:00                            1.741388
# 2013-08-01 01:00:00                            1.435624
# 2013-08-01 02:00:00                            1.995486

# %%
plt.figure(figsize=(15,5))
pd.plotting.autocorrelation_plot(ts_logcpu);
pd.plotting.autocorrelation_plot(ts_logreceive);
pd.plotting.autocorrelation_plot(ts_logtransmit);

# %%
# Importing metrics

from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error

def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


def moving_average(series, n):
    """
        Calculate average of last n observations
    """
    return np.average(series[-n:])

moving_average(ts_logcpu, 24) # prediction for the last observed day (past 24 hours)
# Out:
# 1.163329629682557

# %%
def plotMovingAverage(series, window, plot_intervals=False, scale=1.96, plot_anomalies=False):

    """
        series - dataframe with timeseries
        window - rolling window size 
        plot_intervals - show confidence intervals
        plot_anomalies - show anomalies 
    """
    rolling_mean = series.rolling(window=window).mean()

    plt.figure(figsize=(15,5))
    plt.title("Moving average\n window size = {}".format(window))
    plt.plot(rolling_mean, "g", label="Rolling mean trend")

    # Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bond = rolling_mean - (mae + scale * deviation)
        upper_bond = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bond, "r--", label="Upper Bond / Lower Bond")
        plt.plot(lower_bond, "r--")
        
        # Having the intervals, find abnormal values
        if plot_anomalies:
            anomalies = pd.DataFrame(index=series.index, columns=series.columns)
            anomalies[series<lower_bond] = series[series<lower_bond]
            anomalies[series>upper_bond] = series[series>upper_bond]
            plt.plot(anomalies, "ro", markersize=10)
        
    plt.plot(series[window:], label="Actual values")
    plt.legend(loc="upper left")
    plt.grid(True)

# %%
plotMovingAverage(ts_logcpu, 24, plot_intervals=True, plot_anomalies=True)

# %%
plotMovingAverage(ts_logreceive, 24, plot_intervals=True, plot_anomalies=True)

# %%
plotMovingAverage(ts_logtransmit, 24, plot_intervals=True, plot_anomalies=True)

# %%
hourly_moving_avg_diff = ts_logcpu - moving_avg
ts_log_moving_avg_diff.dropna(inplace=True)
ts_log_moving_avg_diff.head(12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-332-6aab01e26bd3> in <module>()
# ----> 1 hourly_moving_avg_diff = ts_logcpu - moving_avg
#       2 ts_log_moving_avg_diff.dropna(inplace=True)
#       3 ts_log_moving_avg_diff.head(12)
#
# NameError: name 'moving_avg' is not defined

# %%
concatenated_df.head()
# Out:
#                      CPU cores  CPU usage [MHZ]  CPU usage [%]  \
# Timestamp
# 2013-07-31 22:02:56          2       747.105193      12.766667
# 2013-07-31 22:07:56          2       672.979873      11.500000
# 2013-07-31 22:12:56          2       743.203860      12.700000
# 2013-07-31 22:17:56          2       758.809191      12.966667
# 2013-07-31 22:22:56          2       661.275876      11.300000
#
#                      Disk read throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:02:56                          0.0
# 2013-07-31 22:07:56                          0.0
# 2013-07-31 22:12:56                          0.0
# 2013-07-31 22:17:56                          0.0
# 2013-07-31 22:22:56                          0.0
#
#                      Disk write throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:02:56                      1.000000
# 2013-07-31 22:07:56                      1.000000
# 2013-07-31 22:12:56                      1.000000
# 2013-07-31 22:17:56                      1.000000
# 2013-07-31 22:22:56                      0.933333
#
#                      Network received throughput [KB/s]  \
# Timestamp
# 2013-07-31 22:02:56                           11.000000
# 2013-07-31 22:07:56                           13.466667
# 2013-07-31 22:12:56                           13.400000
# 2013-07-31 22:17:56                           11.866667
# 2013-07-31 22:22:56                           13.333333
#
#                      Network transmitted throughput [KB/s]  weekday  weekend  \
# Timestamp
# 2013-07-31 22:02:56                              27.200000        2      0.0
# 2013-07-31 22:07:56                              30.666667        2      0.0
# 2013-07-31 22:12:56                              33.466667        2      0.0
# 2013-07-31 22:17:56                              27.666667        2      0.0
# 2013-07-31 22:22:56                              31.933333        2      0.0
#
#                      month  day  CPU usage prev  CPU_diff  received_prev  \
# Timestamp
# 2013-07-31 22:02:56      7   31             NaN       NaN            NaN
# 2013-07-31 22:07:56      7   31       12.766667 -1.266667      11.000000
# 2013-07-31 22:12:56      7   31       11.500000  1.200000      13.466667
# 2013-07-31 22:17:56      7   31       12.700000  0.266667      13.400000
# 2013-07-31 22:22:56      7   31       12.966667 -1.666667      11.866667
#
#                      received_diff  transmitted_prev  transmitted_diff
# Timestamp
# 2013-07-31 22:02:56            NaN               NaN               NaN
# 2013-07-31 22:07:56       2.466667         27.200000          3.466667
# 2013-07-31 22:12:56      -0.066667         30.666667          2.800000
# 2013-07-31 22:17:56      -1.533333         33.466667         -5.800000
# 2013-07-31 22:22:56       1.466667         27.666667          4.266667

# %%
by_time = concatenated_df.groupby(['weekday']).mean()

# %%
by_time.head()
# Out:
#          CPU cores  CPU usage [MHZ]  CPU usage [%]  \
# weekday
# 0         2.882628       401.957882       4.245909
# 1         2.882910       563.060227       5.709257
# 2         2.879584       405.686852       4.304048
# 3         2.873416       410.632848       4.383880
# 4         2.893613       488.576145       5.080775
#
#          Disk read throughput [KB/s]  Disk write throughput [KB/s]  \
# weekday
# 0                           2.006127                     35.819464
# 1                           2.888852                     57.851946
# 2                           5.410468                     19.389570
# 3                           9.164727                     45.549578
# 4                          18.790114                     59.537820
#
#          Network received throughput [KB/s]  \
# weekday
# 0                                  6.733847
# 1                                  8.898677
# 2                                  8.179311
# 3                                 13.892017
# 4                                  8.477589
#
#          Network transmitted throughput [KB/s]  weekend     month        day  \
# weekday
# 0                                     4.532436      0.0  8.000000  15.471873
# 1                                     7.690844      0.0  8.000000  16.502330
# 2                                    10.330463      0.0  7.979584  17.771881
# 3                                    15.534393      0.0  8.000000  14.984372
# 4                                    22.820654      0.0  8.000000  15.834878
#
#          CPU usage prev  CPU_diff  received_prev  received_diff  \
# weekday
# 0              4.236505  0.009404       6.723996       0.009851
# 1              5.710925 -0.001668       8.902782      -0.004104
# 2              4.305126 -0.001142       8.183523      -0.004234
# 3              4.384472 -0.000592      13.869254       0.022763
# 4              5.075949  0.004826       8.500114      -0.022524
#
#          transmitted_prev  transmitted_diff
# weekday
# 0                4.520779          0.011657
# 1                7.688508          0.002336
# 2               10.337562         -0.007229
# 3               15.453290          0.081103
# 4               22.906040         -0.085386

# %% [markdown]
# Augmented Dickey-Fuller Test
# Time Series models are described in terms of autoregressive (AR) lags. So an AR(1) model states that the value at Yt depends on the value at Yt-1. So we can represent the time series as a model:
#
# Yt = Alpha + Rho*Yt-1 + Errort
#
# It turns out, a time series is perfectly stationary when Rho = 0. This makes intuitive sense: The time series will not depend on its previous value when Rho is 0, so it depends entirely on error and is equivalent to a random walk. A time series is perfectly non-stationary if Rho = 1. Alpha is a coeffecient that we want to estimate such that the Error term is minimized, but let's worry about that later.
#
# The Dickey-Fuller Test asks if Rho in an AR(1) model is equal to 0 (H0: Rho=1, H1: Rho<1)
#
# The augmented Dickey-Fuller Test just expands this to work for AR(n) models
#
# A p-value < 0.05 indicates that your time series IS STATIONARY.

# %%
from statsmodels.tsa.stattools import adfuller

# %%
dftest = adfuller(ts_logreceive['Network received throughput [KB/s]'], autolag='AIC')

# the statsmodels output is ugly and unlabeled, lets use a function to format it nicely
def adf_output(dftest):
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','# of Lags Used','Number of Observations Used'])

    # the last element is a dictionary to unpack
    for key,value in dftest[4].items(): 
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
adf_output(dftest)
# Out:
# Test Statistic                -5.819483e+00
# p-value                        4.215715e-07
# # of Lags Used                 4.000000e+00
# Number of Observations Used    7.150000e+02
# Critical Value (1%)           -3.439529e+00
# Critical Value (5%)           -2.865591e+00
# Critical Value (10%)          -2.568927e+00
# dtype: float64

# %%
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

decomp = seasonal_decompose(ts_logreceive['Network received throughput [KB/s]'], model="additive")

plt.figure(figsize=(15,5))
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4)
fig.set_size_inches(11.7, 8.27)

ax1.plot(ts_logreceive['Network received throughput [KB/s]'])
ax2.plot(decomp.trend)
ax3.plot(decomp.seasonal)
ax4.plot(decomp.resid)
sns.despine()

# %%
resid = decomp.resid.dropna()
decomp_adf = adfuller(resid, autolag='AIC')
adf_output(decomp_adf)
# Out:
# Test Statistic                -1.024326e+01
# p-value                        4.688914e-18
# # of Lags Used                 1.900000e+01
# Number of Observations Used    6.760000e+02
# Critical Value (1%)           -3.440061e+00
# Critical Value (5%)           -2.865825e+00
# Critical Value (10%)          -2.569052e+00
# dtype: float64

# %%
decomp = seasonal_decompose(ts_logcpu['CPU usage [%]'], model="additive")

plt.figure(figsize=(15,5))
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4)

ax1.plot(ts_logcpu['CPU usage [%]'])
ax2.plot(decomp.trend)
ax3.plot(decomp.seasonal)
ax4.plot(decomp.resid)
fig.set_size_inches(11.7, 8.27)

sns.despine()

residcpu = decomp.resid.dropna()
decomp_adf_cpu = adfuller(residcpu, autolag='AIC')
adf_output(decomp_adf_cpu)
# Out:
# Test Statistic                -1.124949e+01
# p-value                        1.726240e-20
# # of Lags Used                 8.000000e+00
# Number of Observations Used    6.870000e+02
# Critical Value (1%)           -3.439904e+00
# Critical Value (5%)           -2.865756e+00
# Critical Value (10%)          -2.569015e+00
# dtype: float64

# %%
decomp = seasonal_decompose(ts_logtransmit['Network transmitted throughput [KB/s]'], model="additive")

plt.figure(figsize=(15,5))
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4)
fig.set_size_inches(11.7, 8.27)

ax1.plot(ts_logtransmit['Network transmitted throughput [KB/s]'])
ax2.plot(decomp.trend)
ax3.plot(decomp.seasonal)
ax4.plot(decomp.resid)
sns.despine()

residtrans = decomp.resid.dropna()
decomp_adftrans = adfuller(residtrans, autolag='AIC')
adf_output(decomp_adftrans)
# Out:
# Test Statistic                -1.027515e+01
# p-value                        3.908357e-18
# # of Lags Used                 1.600000e+01
# Number of Observations Used    6.790000e+02
# Critical Value (1%)           -3.440017e+00
# Critical Value (5%)           -2.865806e+00
# Critical Value (10%)          -2.569042e+00
# dtype: float64

# %%
sns.heatmap(hourlycpu, annot=True)

# %%
# construct difference curve and plot
diffed = ts_logtransmit['Network transmitted throughput [KB/s]'] - ts_logtransmit['Network transmitted throughput [KB/s]'].shift()
diffed.dropna(inplace=True)
plt.plot(diffed)
sns.despine()

# %%
diffed_adf = adfuller(diffed, autolag='AIC')
adf_output(diffed_adf)
# Out:
# Test Statistic                -1.033416e+01
# p-value                        2.792055e-18
# # of Lags Used                 1.600000e+01
# Number of Observations Used    7.020000e+02
# Critical Value (1%)           -3.439700e+00
# Critical Value (5%)           -2.865666e+00
# Critical Value (10%)          -2.568967e+00
# dtype: float64

# %%
# construct difference curve and plot
diffed = ts_logreceive['Network received throughput [KB/s]'] - ts_logreceive['Network received throughput [KB/s]'].shift()
diffed.dropna(inplace=True)
plt.plot(diffed)
sns.despine()
diffed_adf = adfuller(diffed, autolag='AIC')
adf_output(diffed_adf)
# Out:
# Test Statistic                -9.687527e+00
# p-value                        1.159809e-16
# # of Lags Used                 1.400000e+01
# Number of Observations Used    7.040000e+02
# Critical Value (1%)           -3.439673e+00
# Critical Value (5%)           -2.865654e+00
# Critical Value (10%)          -2.568961e+00
# dtype: float64

# %%
# construct difference curve and plot
diffed = ts_logcpu['CPU usage [%]'] - ts_logcpu['CPU usage [%]'].shift()
diffed.dropna(inplace=True)
plt.plot(diffed)
sns.despine()
diffed_adf = adfuller(diffed, autolag='AIC')
adf_output(diffed_adf)
# Out:
# Test Statistic                 -26.820688
# p-value                          0.000000
# # of Lags Used                   0.000000
# Number of Observations Used    718.000000
# Critical Value (1%)             -3.439490
# Critical Value (5%)             -2.865574
# Critical Value (10%)            -2.568918
# dtype: float64

# %%
plt.figure(figsize=(10,5))
pd.plotting.autocorrelation_plot(residtrans);

# %%
from pandas import read_csv
from pandas import datetime
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
 
def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')
 
# fit model
model = ARIMA(ts_logcpu, order=(10,0,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()

#mean is pretty close to 0
print(residuals.describe())
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          CPU usage [%]   No. Observations:                  720
# Model:                    ARMA(10, 0)   Log Likelihood                 148.031
# Method:                       css-mle   S.D. of innovations              0.197
# Date:                Mon, 11 Jun 2018   AIC                           -272.062
# Time:                        12:37:20   BIC                           -217.111
# Sample:                    07-31-2013   HQIC                          -250.848
#                          - 08-30-2013
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    1.4041      0.070     20.100      0.000       1.267       1.541
# ar.L1.CPU usage [%]      0.9455      0.037     25.401      0.000       0.873       1.018
# ar.L2.CPU usage [%]     -0.0102      0.051     -0.199      0.843      -0.111       0.090
# ar.L3.CPU usage [%]      0.0220      0.051      0.429      0.668      -0.078       0.122
# ar.L4.CPU usage [%]      0.0179      0.051      0.349      0.727      -0.083       0.119
# ar.L5.CPU usage [%]     -0.0460      0.052     -0.892      0.373      -0.147       0.055
# ar.L6.CPU usage [%]     -0.0393      0.052     -0.762      0.446      -0.140       0.062
# ar.L7.CPU usage [%]      0.0068      0.052      0.132      0.895      -0.094       0.108
# ar.L8.CPU usage [%]      0.0170      0.051      0.330      0.742      -0.084       0.118
# ar.L9.CPU usage [%]     -0.0464      0.052     -0.899      0.369      -0.148       0.055
# ar.L10.CPU usage [%]     0.0286      0.038      0.761      0.447      -0.045       0.102
#                                     Roots
# ==============================================================================
#                   Real           Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1            -1.4318           -0.0000j            1.4318           -0.5000
# AR.2            -1.0918           -0.9314j            1.4351           -0.3876
# AR.3            -1.0918           +0.9314j            1.4351            0.3876
# AR.4            -0.1503           -1.4076j            1.4156           -0.2669
# AR.5            -0.1503           +1.4076j            1.4156            0.2669
# AR.6             0.7809           -1.3610j            1.5691           -0.1671
# AR.7             0.7809           +1.3610j            1.5691            0.1671
# AR.8             1.3869           -0.2696j            1.4128           -0.0306
# AR.9             1.3869           +0.2696j            1.4128            0.0306
# AR.10            1.2045           -0.0000j            1.2045           -0.0000
# ------------------------------------------------------------------------------
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
#                 0
# count  720.000000
# mean     0.000468
# std      0.198490
# min     -1.046539
# 25%     -0.071657
# 50%     -0.003314
# 75%      0.067656
# max      1.015867

# %%
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
 
def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')
 
X = ts_logcpu['CPU usage [%]']
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(10,0,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# predicted=1.867509, expected=1.883459
# predicted=1.858437, expected=1.453969
# predicted=1.423146, expected=1.488065
# predicted=1.501614, expected=1.420526
# predicted=1.422015, expected=1.546662
# predicted=1.547450, expected=1.362584
# predicted=1.321421, expected=0.570185
# predicted=0.561902, expected=0.575799
# predicted=0.654117, expected=0.607549
# predicted=0.634774, expected=0.604682
# predicted=0.633980, expected=0.561126
# predicted=0.588086, expected=0.563554
# predicted=0.653359, expected=1.230111
# predicted=1.376028, expected=1.187834
# predicted=1.226397, expected=0.755942
# predicted=0.805246, expected=1.019406
# predicted=1.110960, expected=1.488737
# predicted=1.544083, expected=1.495987
# predicted=1.468212, expected=1.538708
# predicted=1.524951, expected=2.010007
# predicted=2.084912, expected=2.224005
# predicted=2.220973, expected=1.889935
# predicted=1.821720, expected=1.662801
# predicted=1.668473, expected=1.497161
# predicted=1.492385, expected=1.924728
# predicted=1.875562, expected=1.928066
# predicted=1.812575, expected=1.934018
# predicted=1.918730, expected=1.664108
# predicted=1.667166, expected=1.802577
# predicted=1.804678, expected=1.477107
# predicted=1.409724, expected=1.466949
# predicted=1.421853, expected=1.464138
# predicted=1.460332, expected=1.223884
# predicted=1.207338, expected=0.620784
# predicted=0.627514, expected=0.575744
# predicted=0.620746, expected=0.575463
# predicted=0.618732, expected=0.568409
# predicted=0.571603, expected=0.630309
# predicted=0.696016, expected=1.530588
# predicted=1.651423, expected=1.683736
# predicted=1.709303, expected=1.780223
# predicted=1.814235, expected=1.813269
# predicted=1.889363, expected=1.670214
# predicted=1.666614, expected=1.699692
# predicted=1.668762, expected=1.712481
# predicted=1.647480, expected=1.537731
# predicted=1.528414, expected=2.371021
# predicted=2.367746, expected=1.718930
# predicted=1.641963, expected=1.592032
# predicted=1.603808, expected=1.701113
# predicted=1.674341, expected=1.744796
# predicted=1.692051, expected=1.642061
# predicted=1.592555, expected=1.703003
# predicted=1.642026, expected=1.660070
# predicted=1.735574, expected=1.640208
# predicted=1.539546, expected=1.752140
# predicted=1.736449, expected=1.703641
# predicted=1.681417, expected=1.550744
# predicted=1.535849, expected=1.680317
# predicted=1.659852, expected=1.705329
# predicted=1.678988, expected=1.559194
# predicted=1.528472, expected=1.591772
# predicted=1.582421, expected=1.433212
# predicted=1.425768, expected=1.478826
# predicted=1.469589, expected=1.172952
# predicted=1.148869, expected=1.134386
# predicted=1.163631, expected=1.434968
# predicted=1.443349, expected=1.498287
# predicted=1.468757, expected=1.485439
# predicted=1.510335, expected=1.898369
# predicted=1.906130, expected=2.061174
# predicted=2.051853, expected=2.081462
# predicted=2.032503, expected=1.990812
# predicted=1.965443, expected=2.063377
# predicted=2.045542, expected=2.018917
# predicted=1.943668, expected=1.991136
# predicted=1.907422, expected=2.006970
# predicted=1.972138, expected=1.923925
# predicted=1.860252, expected=1.668943
# predicted=1.618429, expected=1.642655
# predicted=1.600555, expected=1.194743
# predicted=1.161398, expected=1.699733
# predicted=1.678329, expected=1.560492
# predicted=1.508584, expected=1.672801
# predicted=1.666532, expected=1.357806
# predicted=1.381323, expected=1.629923
# predicted=1.611404, expected=1.694936
# predicted=1.697534, expected=1.572575
# predicted=1.495377, expected=1.451505
# predicted=1.522082, expected=1.442607
# predicted=1.413872, expected=1.573000
# predicted=1.574992, expected=1.579040
# predicted=1.521251, expected=1.562220
# predicted=1.583159, expected=1.555137
# predicted=1.560265, expected=1.565670
# predicted=1.553239, expected=1.607324
# predicted=1.588972, expected=1.719436
# predicted=1.699538, expected=1.694736
# predicted=1.684436, expected=1.641685
# predicted=1.627610, expected=0.851746
# predicted=0.864009, expected=0.842957
# predicted=0.880698, expected=0.767618
# predicted=0.778512, expected=0.807804
# predicted=0.804140, expected=0.768025
# predicted=0.832011, expected=0.834295
# predicted=0.908063, expected=0.940646
# predicted=1.041411, expected=0.659327
# predicted=0.683639, expected=1.551720
# predicted=1.631310, expected=1.548771
# predicted=1.565896, expected=1.624661
# predicted=1.651502, expected=1.622713
# predicted=1.680606, expected=1.578749
# predicted=1.593148, expected=1.681114
# predicted=1.663425, expected=1.604648
# predicted=1.549644, expected=1.426804
# predicted=1.458723, expected=1.558301
# predicted=1.519287, expected=1.244831
# predicted=1.244120, expected=1.440913
# predicted=1.428253, expected=0.585609
# predicted=0.635927, expected=0.593236
# predicted=0.642951, expected=0.603320
# predicted=0.652465, expected=0.605207
# predicted=0.627183, expected=0.634112
# predicted=0.722034, expected=0.610250
# predicted=0.702924, expected=0.609076
# predicted=0.753736, expected=0.605556
# predicted=0.658478, expected=0.604428
# predicted=0.734649, expected=0.605330
# predicted=0.695736, expected=0.632232
# predicted=0.721085, expected=0.641814
# predicted=0.731987, expected=0.602163
# predicted=0.689923, expected=0.598313
# predicted=0.689157, expected=0.597817
# predicted=0.684995, expected=0.599033
# predicted=0.682077, expected=0.608134
# predicted=0.691451, expected=0.884722
# predicted=0.958272, expected=1.003973
# predicted=1.071399, expected=0.947097
# predicted=1.016682, expected=1.024240
# predicted=1.101577, expected=0.970766
# predicted=1.035288, expected=1.083453
# predicted=1.118207, expected=1.378549
# predicted=1.396530, expected=1.498226
# predicted=1.525714, expected=1.520397
# predicted=1.537410, expected=1.514150
# predicted=1.535341, expected=1.516660
# predicted=1.533910, expected=1.517457
# predicted=1.499840, expected=1.518337
# predicted=1.505934, expected=1.515173
# predicted=1.509359, expected=1.512107
# predicted=1.495427, expected=1.502876
# predicted=1.491134, expected=1.498597
# predicted=1.489825, expected=1.511249
# predicted=1.503403, expected=1.516614
# predicted=1.508114, expected=1.485550
# predicted=1.479507, expected=1.483340
# predicted=1.478310, expected=1.682872
# predicted=1.666696, expected=1.958717
# predicted=1.926193, expected=1.968670
# predicted=1.938295, expected=1.907910
# predicted=1.890766, expected=1.933230
# predicted=1.911789, expected=2.061327
# predicted=2.005607, expected=1.486191
# predicted=1.443511, expected=1.528035
# predicted=1.499310, expected=1.498183
# predicted=1.474004, expected=1.480686
# predicted=1.418046, expected=1.512003
# predicted=1.484580, expected=1.950589
# predicted=1.930837, expected=1.868141
# predicted=1.860910, expected=0.786858
# predicted=0.799804, expected=0.707629
# predicted=0.806909, expected=0.711475
# predicted=0.724395, expected=0.716307
# predicted=0.684986, expected=0.738128
# predicted=0.790681, expected=0.720765
# predicted=0.831670, expected=0.721951
# predicted=0.784851, expected=0.709436
# predicted=0.756926, expected=0.732010
# predicted=0.851448, expected=0.667513
# predicted=0.749378, expected=0.644259
# predicted=0.725841, expected=0.650844
# predicted=0.732570, expected=0.671861
# predicted=0.746655, expected=0.698300
# predicted=0.775656, expected=0.688428
# predicted=0.768707, expected=0.711430
# predicted=0.792696, expected=0.714338
# predicted=0.788892, expected=0.697324
# predicted=0.774166, expected=0.703888
# predicted=0.780437, expected=1.048907
# predicted=1.109144, expected=1.273656
# predicted=1.315270, expected=1.167661
# predicted=1.214491, expected=1.740453
# predicted=1.782113, expected=1.571465
# predicted=1.589949, expected=1.726974
# predicted=1.720990, expected=1.565318
# predicted=1.583759, expected=1.758419
# predicted=1.744652, expected=1.606541
# predicted=1.577638, expected=1.749471
# predicted=1.704314, expected=1.752622
# predicted=1.751449, expected=0.835777
# predicted=0.840077, expected=0.753175
# predicted=0.794176, expected=0.766605
# predicted=0.780506, expected=0.722107
# predicted=0.715868, expected=0.711132
# predicted=0.751183, expected=0.707234
# predicted=0.801530, expected=0.708408
# predicted=0.772267, expected=0.818301
# predicted=0.872355, expected=0.785473
# predicted=0.882634, expected=0.792819
# predicted=0.868660, expected=0.831062
# predicted=0.903196, expected=0.752785
# predicted=0.822722, expected=1.042557
# predicted=1.095569, expected=0.784454
# predicted=0.852299, expected=0.774665
# predicted=0.844421, expected=0.770661
# predicted=0.841194, expected=0.757181
# predicted=0.812399, expected=0.756876
# predicted=0.813308, expected=0.759609
# predicted=0.829060, expected=0.753970
# predicted=0.827359, expected=0.760985
# predicted=0.815638, expected=0.745047
# predicted=0.820558, expected=0.748797
# predicted=0.816090, expected=0.746394
# predicted=0.813269, expected=0.762754
# predicted=0.828411, expected=0.782185
# predicted=0.846688, expected=0.772073
# predicted=0.837238, expected=0.716577
# predicted=0.785177, expected=0.698447
# predicted=0.766559, expected=0.691997
# predicted=0.758040, expected=0.695658
# predicted=0.758928, expected=0.695903
# predicted=0.762786, expected=0.728208
# predicted=0.795538, expected=0.703687
# predicted=0.771444, expected=0.693517
# predicted=0.762040, expected=0.667378
# predicted=0.738901, expected=1.139763
# predicted=1.182962, expected=1.737586
# predicted=1.751158, expected=1.690649
# predicted=1.707318, expected=1.592458
# predicted=1.637929, expected=1.744968
# predicted=1.771534, expected=1.586502
# predicted=1.559802, expected=2.116785
# predicted=2.058027, expected=2.120750
# predicted=2.078518, expected=1.982232
# predicted=1.932146, expected=2.104641
# Test MSE: 0.054

# %%
#predictionsdf=pd.DataFrame(predictions)

# %%
test.head()
# Out:
# Timestamp
# 2013-08-20 17:00:00    1.883459
# 2013-08-20 18:00:00    1.453969
# 2013-08-20 19:00:00    1.488065
# 2013-08-20 20:00:00    1.420526
# 2013-08-20 21:00:00    1.546662
# Freq: H, Name: CPU usage [%], dtype: float64

# %%
predictions
# Out:
# [array([1.86750868]),
#  array([1.85843733]),
#  array([1.42314559]),
#  array([1.50161398]),
#  array([1.42201457]),
#  array([1.54744998]),
#  array([1.32142057]),
#  array([0.56190211]),
#  array([0.65411679]),
#  array([0.63477361]),
#  array([0.63398019]),
#  array([0.58808615]),
#  array([0.65335944]),
#  array([1.37602766]),
#  array([1.22639718]),
#  array([0.80524593]),
#  array([1.11096045]),
#  array([1.54408344]),
#  array([1.46821195]),
#  array([1.52495089]),
#  array([2.0849121]),
#  array([2.22097337]),
#  array([1.82172018]),
#  array([1.66847329]),
#  array([1.49238518]),
#  array([1.87556177]),
#  array([1.81257513]),
#  array([1.91872988]),
#  array([1.66716619]),
#  array([1.80467822]),
#  array([1.40972419]),
#  array([1.42185345]),
#  array([1.46033158]),
#  array([1.20733845]),
#  array([0.62751354]),
#  array([0.62074554]),
#  array([0.61873162]),
#  array([0.57160335]),
#  array([0.69601629]),
#  array([1.65142317]),
#  array([1.70930302]),
#  array([1.81423459]),
#  array([1.88936253]),
#  array([1.66661421]),
#  array([1.66876228]),
#  array([1.64748002]),
#  array([1.52841372]),
#  array([2.36774577]),
#  array([1.64196281]),
#  array([1.60380751]),
#  array([1.67434106]),
#  array([1.69205116]),
#  array([1.59255515]),
#  array([1.64202635]),
#  array([1.73557356]),
#  array([1.539546]),
#  array([1.73644852]),
#  array([1.68141679]),
#  array([1.53584941]),
#  array([1.6598516]),
#  array([1.67898769]),
#  array([1.52847166]),
#  array([1.58242066]),
#  array([1.4257677]),
#  array([1.46958883]),
#  array([1.14886932]),
#  array([1.16363135]),
#  array([1.44334903]),
#  array([1.4687565]),
#  array([1.51033519]),
#  array([1.90613018]),
#  array([2.05185293]),
#  array([2.03250311]),
#  array([1.96544326]),
#  array([2.04554193]),
#  array([1.94366786]),
#  array([1.90742209]),
#  array([1.97213796]),
#  array([1.86025171]),
#  array([1.6184293]),
#  array([1.60055513]),
#  array([1.16139762]),
#  array([1.67832885]),
#  array([1.50858448]),
#  array([1.6665322]),
#  array([1.38132257]),
#  array([1.61140435]),
#  array([1.6975342]),
#  array([1.49537679]),
#  array([1.52208188]),
#  array([1.41387166]),
#  array([1.5749916]),
#  array([1.52125085]),
#  array([1.58315883]),
#  array([1.56026452]),
#  array([1.55323872]),
#  array([1.58897226]),
#  array([1.69953809]),
#  array([1.68443616]),
#  array([1.62760985]),
#  array([0.86400949]),
#  array([0.88069826]),
#  array([0.77851236]),
#  array([0.80413954]),
#  array([0.83201149]),
#  array([0.90806253]),
#  array([1.04141099]),
#  array([0.68363925]),
#  array([1.63131036]),
#  array([1.56589575]),
#  array([1.65150208]),
#  array([1.68060585]),
#  array([1.59314772]),
#  array([1.66342452]),
#  array([1.54964389]),
#  array([1.45872306]),
#  array([1.51928677]),
#  array([1.2441198]),
#  array([1.42825298]),
#  array([0.63592673]),
#  array([0.64295055]),
#  array([0.65246543]),
#  array([0.62718254]),
#  array([0.72203435]),
#  array([0.70292356]),
#  array([0.75373584]),
#  array([0.65847784]),
#  array([0.73464883]),
#  array([0.69573609]),
#  array([0.72108515]),
#  array([0.73198723]),
#  array([0.68992293]),
#  array([0.68915671]),
#  array([0.68499459]),
#  array([0.68207699]),
#  array([0.69145076]),
#  array([0.95827225]),
#  array([1.07139858]),
#  array([1.01668187]),
#  array([1.10157743]),
#  array([1.0352877]),
#  array([1.11820671]),
#  array([1.39653045]),
#  array([1.52571447]),
#  array([1.53741006]),
#  array([1.53534121]),
#  array([1.53391015]),
#  array([1.49984022]),
#  array([1.50593402]),
#  array([1.50935942]),
#  array([1.49542714]),
#  array([1.49113411]),
#  array([1.48982527]),
#  array([1.50340277]),
#  array([1.50811427]),
#  array([1.47950699]),
#  array([1.47831032]),
#  array([1.66669602]),
#  array([1.92619337]),
#  array([1.93829504]),
#  array([1.89076552]),
#  array([1.91178917]),
#  array([2.00560662]),
#  array([1.44351125]),
#  array([1.4993099]),
#  array([1.47400415]),
#  array([1.41804627]),
#  array([1.48458033]),
#  array([1.93083694]),
#  array([1.86091009]),
#  array([0.79980448]),
#  array([0.8069088]),
#  array([0.72439468]),
#  array([0.68498564]),
#  array([0.79068119]),
#  array([0.83167044]),
#  array([0.78485066]),
#  array([0.75692555]),
#  array([0.8514476]),
#  array([0.7493782]),
#  array([0.72584105]),
#  array([0.73257041]),
#  array([0.74665548]),
#  array([0.77565628]),
#  array([0.76870688]),
#  array([0.79269615]),
#  array([0.78889222]),
#  array([0.77416596]),
#  array([0.7804371]),
#  array([1.10914358]),
#  array([1.31527006]),
#  array([1.21449116]),
#  array([1.78211275]),
#  array([1.58994864]),
#  array([1.72098973]),
#  array([1.58375874]),
#  array([1.7446524]),
#  array([1.57763841]),
#  array([1.70431358]),
#  array([1.75144939]),
#  array([0.84007702]),
#  array([0.79417647]),
#  array([0.78050646]),
#  array([0.71586773]),
#  array([0.75118339]),
#  array([0.80152979]),
#  array([0.77226705]),
#  array([0.87235495]),
#  array([0.88263373]),
#  array([0.86866009]),
#  array([0.90319613]),
#  array([0.82272247]),
#  array([1.0955693]),
#  array([0.85229889]),
#  array([0.84442051]),
#  array([0.84119409]),
#  array([0.81239874]),
#  array([0.81330772]),
#  array([0.82906047]),
#  array([0.8273593]),
#  array([0.81563808]),
#  array([0.82055843]),
#  array([0.81609038]),
#  array([0.81326913]),
#  array([0.82841141]),
#  array([0.84668774]),
#  array([0.83723766]),
#  array([0.78517685]),
#  array([0.76655921]),
#  array([0.75803963]),
#  array([0.75892809]),
#  array([0.76278632]),
#  array([0.79553763]),
#  array([0.77144409]),
#  array([0.76203964]),
#  array([0.7389012]),
#  array([1.18296157]),
#  array([1.75115777]),
#  array([1.70731783]),
#  array([1.63792927]),
#  array([1.77153417]),
#  array([1.55980187]),
#  array([2.05802705]),
#  array([2.0785182]),
#  array([1.93214596])]

# %%
testnew = test

# %%
testnew= testnew.reset_index(drop = True)
testnew
# Out:
# 0      1.883459
# 1      1.453969
# 2      1.488065
# 3      1.420526
# 4      1.546662
# 5      1.362584
# 6      0.570185
# 7      0.575799
# 8      0.607549
# 9      0.604682
# 10     0.561126
# 11     0.563554
# 12     1.230111
# 13     1.187834
# 14     0.755942
# 15     1.019406
# 16     1.488737
# 17     1.495987
# 18     1.538708
# 19     2.010007
# 20     2.224005
# 21     1.889935
# 22     1.662801
# 23     1.497161
# 24     1.924728
# 25     1.928066
# 26     1.934018
# 27     1.664108
# 28     1.802577
# 29     1.477107
#          ...
# 215    0.757181
# 216    0.756876
# 217    0.759609
# 218    0.753970
# 219    0.760985
# 220    0.745047
# 221    0.748797
# 222    0.746394
# 223    0.762754
# 224    0.782185
# 225    0.772073
# 226    0.716577
# 227    0.698447
# 228    0.691997
# 229    0.695658
# 230    0.695903
# 231    0.728208
# 232    0.703687
# 233    0.693517
# 234    0.667378
# 235    1.139763
# 236    1.737586
# 237    1.690649
# 238    1.592458
# 239    1.744968
# 240    1.586502
# 241    2.116785
# 242    2.120750
# 243    1.982232
# 244    2.104641
# Name: CPU usage [%], Length: 245, dtype: float64

# %%
prednew = pd.Series( (v[0] for v in predictions) )
prednew.head()
# Out:
# 0    1.867509
# 1    1.858437
# 2    1.423146
# 3    1.501614
# 4    1.422015
# dtype: float64

# %%
pyplot.plot(testnew)
pyplot.plot(prednew, color='red')
pyplot.title("ARIMA Model Predictions (in red)")
pyplot.show()
